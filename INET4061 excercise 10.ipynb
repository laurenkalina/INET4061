# %%
import quandl
import pandas as pd
quandl.ApiConfig.api_key = 'biMVR8grXNerNjmik11a'

# %% [markdown]
# API key for quandl:
# biMVR8grXNerNjmik11a

# %%
# Retrieve TSLA data from Quandl
jnj = quandl.get("WIKI/JNJ", authtoken="biMVR8grXNerNjmik11a")

# %%
# Plot our time series

# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('seaborn') 


plt.plot(jnj.index, jnj['Adj. Close'], 'r')
plt.title('Johnson & Johnson')
plt.ylabel('Price ($)');

# %%
#select only the most recent 150 values by date
jnj = jnj.last('150D')

#plot the ACF and PACF plots

import statsmodels.api as sm

fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(jnj['Adj. Close'].diff().dropna(), lags=50, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(jnj['Adj. Close'].diff().dropna(), lags=50, ax=ax2)
plt.show()
